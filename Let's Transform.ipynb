# %%
airbnb_df = spark.read.format('csv').option("header","true").option("inferSchema","true").load('/FileStore/tables/listings-1.csv')
display(airbnb_df.limit(5))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>name</th><th>host_id</th><th>host_name</th><th>neighbourhood_group</th><th>neighbourhood</th><th>latitude</th><th>longitude</th><th>room_type</th><th>price</th><th>minimum_nights</th><th>number_of_reviews</th><th>last_review</th><th>reviews_per_month</th><th>calculated_host_listings_count</th><th>availability_365</th></tr></thead><tbody><tr><td>2818</td><td>Quiet Garden View Room & Super Fast WiFi</td><td>3159</td><td>Daniel</td><td>null</td><td>Oostelijk Havengebied - Indische Buurt</td><td>52.36575</td><td>4.94142</td><td>Private room</td><td>59</td><td>3</td><td>278</td><td>2020-02-14</td><td>1.98</td><td>1.0</td><td>0</td></tr><tr><td>20168</td><td>Studio with private bathroom in the centre 1</td><td>59484</td><td>Alexander</td><td>null</td><td>Centrum-Oost</td><td>52.36424</td><td>4.89396</td><td>Private room</td><td>236</td><td>1</td><td>340</td><td>2020-04-09</td><td>2.63</td><td>2.0</td><td>0</td></tr><tr><td>25428</td><td>Lovely apt in City Centre (w.lift) near Jordaan</td><td>56142</td><td>Joan</td><td>null</td><td>Centrum-West</td><td>52.37297</td><td>4.88339</td><td>Entire home/apt</td><td>125</td><td>14</td><td>5</td><td>2020-02-09</td><td>0.15</td><td>1.0</td><td>58</td></tr><tr><td>27886</td><td>Romantic, stylish B&B houseboat in canal district</td><td>97647</td><td>Flip</td><td>null</td><td>Centrum-West</td><td>52.38761</td><td>4.89188</td><td>Private room</td><td>138</td><td>2</td><td>219</td><td>2020-07-25</td><td>2.05</td><td>1.0</td><td>158</td></tr><tr><td>28871</td><td>Comfortable double room</td><td>124245</td><td>Edwin</td><td>null</td><td>Centrum-West</td><td>52.36719</td><td>4.89092</td><td>Private room</td><td>75</td><td>2</td><td>336</td><td>2020-09-20</td><td>2.72</td><td>2.0</td><td>340</td></tr></tbody></table></div>

# %%
airbnb_df.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[20]: 18808</div>

# %%
#Count of Airbnb's booked more than once

airbnb_df.createOrReplaceTempView("airbnb")
airbnb_count = spark.sql("select name,count(*) as count from airbnb group by name having count > 1")
display(airbnb_count.limit(5))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>name</th><th>count</th></tr></thead><tbody><tr><td>Great appartment near the centre</td><td>2</td></tr><tr><td>Cozy Room close to the City Centre</td><td>3</td></tr><tr><td>Cosy apartment</td><td>2</td></tr><tr><td>Cosy apartment in the city centre of Amsterdam</td><td>5</td></tr><tr><td>A beautiful spacious room on a central location.</td><td>2</td></tr></tbody></table></div>

# %%
airbnb_count.agg({"count" :"max"}).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----------+
# max(count)|
# +----------+
#         36|
# +----------+
#
# </div>

# %%
airbnb_count.filter(airbnb_count["count"] == 36).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---------+-----+
#      name|count|
# +---------+-----+
# Amsterdam|   36|
# +---------+-----+
#
# </div>

# %%
#changing the schema of original dataset by casting the particular columns

from pyspark.sql.types import IntegerType
airbnb_df = airbnb_df.withColumn("host_id", airbnb_df["host_id"].cast(IntegerType())).withColumn("id",airbnb_df["id"].cast(IntegerType()))
airbnb_df.dtypes
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[97]: [(&#39;id&#39;, &#39;int&#39;),
#  (&#39;name&#39;, &#39;string&#39;),
#  (&#39;host_id&#39;, &#39;int&#39;),
#  (&#39;host_name&#39;, &#39;string&#39;),
#  (&#39;neighbourhood_group&#39;, &#39;string&#39;),
#  (&#39;neighbourhood&#39;, &#39;string&#39;),
#  (&#39;latitude&#39;, &#39;string&#39;),
#  (&#39;longitude&#39;, &#39;string&#39;),
#  (&#39;room_type&#39;, &#39;string&#39;),
#  (&#39;price&#39;, &#39;string&#39;),
#  (&#39;minimum_nights&#39;, &#39;int&#39;),
#  (&#39;number_of_reviews&#39;, &#39;string&#39;),
#  (&#39;last_review&#39;, &#39;string&#39;),
#  (&#39;reviews_per_month&#39;, &#39;string&#39;),
#  (&#39;calculated_host_listings_count&#39;, &#39;double&#39;),
#  (&#39;availability_365&#39;, &#39;int&#39;)]</div>

# %%
#adding new columns storing true/false values for integerType check on columns -> id/host_id 

import pyspark.sql.functions as F

airbnb_df = airbnb_df.withColumn(
  "value_host_id",
  F.col("host_id").cast("int").isNotNull()).withColumn("value_id",F.col("id").cast("int").isNotNull())

airbnb_df.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- id: integer (nullable = true)
# -- name: string (nullable = true)
# -- host_id: integer (nullable = true)
# -- host_name: string (nullable = true)
# -- neighbourhood_group: string (nullable = true)
# -- neighbourhood: string (nullable = true)
# -- latitude: string (nullable = true)
# -- longitude: string (nullable = true)
# -- room_type: string (nullable = true)
# -- price: string (nullable = true)
# -- minimum_nights: integer (nullable = true)
# -- number_of_reviews: string (nullable = true)
# -- last_review: string (nullable = true)
# -- reviews_per_month: string (nullable = true)
# -- calculated_host_listings_count: double (nullable = true)
# -- availability_365: integer (nullable = true)
# -- value_host_id: boolean (nullable = false)
# -- value_id: boolean (nullable = false)
#
# </div>

# %%
#finding null values in each column

from pyspark.sql.functions import when, count, col
null_df = airbnb_df.select([count(when(col(c).isNull(), c)).alias(c) for c in 
           airbnb_df.columns])
display(null_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>name</th><th>host_id</th><th>host_name</th><th>neighbourhood_group</th><th>neighbourhood</th><th>latitude</th><th>longitude</th><th>room_type</th><th>price</th><th>minimum_nights</th><th>number_of_reviews</th><th>last_review</th><th>reviews_per_month</th><th>calculated_host_listings_count</th><th>availability_365</th><th>value_host_id</th><th>value_id</th></tr></thead><tbody><tr><td>26</td><td>35</td><td>53</td><td>104</td><td>18781</td><td>31</td><td>26</td><td>26</td><td>26</td><td>26</td><td>26</td><td>29</td><td>2316</td><td>2313</td><td>26</td><td>48</td><td>0</td><td>0</td></tr></tbody></table></div>

# %%
#filling -1 values for null values in integer columns

temp = airbnb_df.na.fill(-1)
display(temp.filter((temp.id == -1) & (temp.host_id == -1)).limit(3))
#airbnb_df.count()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>name</th><th>host_id</th><th>host_name</th><th>neighbourhood_group</th><th>neighbourhood</th><th>latitude</th><th>longitude</th><th>room_type</th><th>price</th><th>minimum_nights</th><th>number_of_reviews</th><th>last_review</th><th>reviews_per_month</th><th>calculated_host_listings_count</th><th>availability_365</th><th>value_host_id</th><th>value_id</th></tr></thead><tbody><tr><td>-1</td><td>1344947</td><td>-1</td><td>null</td><td>De Pijp - Rivierenbuurt</td><td>52.34426</td><td>4.88722</td><td>Private room</td><td>155</td><td>2</td><td>90</td><td>2020-08-15</td><td>0.87</td><td>2</td><td>353.0</td><td>-1</td><td>false</td><td>false</td></tr><tr><td>-1</td><td>29582869</td><td>-1</td><td>null</td><td>Noord-West</td><td>52.41495</td><td>4.88927</td><td>Entire home/apt</td><td>190</td><td>7</td><td>1</td><td>2016-08-16</td><td>0.02</td><td>1</td><td>0.0</td><td>-1</td><td>false</td><td>false</td></tr><tr><td>-1</td><td>58563168</td><td>-1</td><td>null</td><td>Zuid</td><td>52.35344</td><td>4.87972</td><td>Entire home/apt</td><td>280</td><td>1</td><td>6</td><td>2017-05-06</td><td>0.11</td><td>1</td><td>0.0</td><td>-1</td><td>false</td><td>false</td></tr></tbody></table></div>

# %%
#display(temp.limit(5))
cleaned_airbnb_df = temp.filter((temp.id != -1) & (temp.host_id != -1))
cleaned_airbnb_df.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[101]: 18753</div>

# %%
#cleaned_airbnb_df.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
'''airbnb_df.dropna(subset=("id","host_id"))
airbnb_df.count()'''
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[103]: &#39;airbnb_df.dropna(subset=(&#34;id&#34;,&#34;host_id&#34;))\nairbnb_df.count()&#39;</div>

# %%
# creating DFs to store details where "id" & "host_id" is not of integer type
'''
null_ids = cleaned_airbnb_df.filter(F.col("value_id") == False )
null_host_id = cleaned_airbnb_df.filter(F.col("value_host_id") == False )'''
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[104]: &#39;\nnull_ids = cleaned_airbnb_df.filter(F.col(&#34;value_id&#34;) == False )\nnull_host_id = cleaned_airbnb_df.filter(F.col(&#34;value_host_id&#34;) == False )&#39;</div>

# %%
#checking the cleaned data for null values
#decreased to 0 for columns -> id,host_id
#reference cmd-5

from pyspark.sql.functions import when, count, col
null_count_df = cleaned_airbnb_df.select([count(when(col(c).isNull(), c)).alias(c) for c in 
           cleaned_airbnb_df.columns])
display(null_count_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>name</th><th>host_id</th><th>host_name</th><th>neighbourhood_group</th><th>neighbourhood</th><th>latitude</th><th>longitude</th><th>room_type</th><th>price</th><th>minimum_nights</th><th>number_of_reviews</th><th>last_review</th><th>reviews_per_month</th><th>calculated_host_listings_count</th><th>availability_365</th><th>value_host_id</th><th>value_id</th></tr></thead><tbody><tr><td>0</td><td>33</td><td>0</td><td>56</td><td>18753</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>2287</td><td>2287</td><td>0</td><td>0</td><td>0</td><td>0</td></tr></tbody></table></div>

# %%
#filtering required columns 

cleaned_airbnb_df = cleaned_airbnb_df.select("id",\
                                             "name","host_id","host_name","neighbourhood","room_type",\
                                             "price","minimum_nights","number_of_reviews",\
                                             "reviews_per_month","availability_365","value_host_id","value_id")
display(cleaned_airbnb_df.limit(3))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>name</th><th>host_id</th><th>host_name</th><th>neighbourhood</th><th>room_type</th><th>price</th><th>minimum_nights</th><th>number_of_reviews</th><th>reviews_per_month</th><th>availability_365</th><th>value_host_id</th><th>value_id</th></tr></thead><tbody><tr><td>2818</td><td>Quiet Garden View Room & Super Fast WiFi</td><td>3159</td><td>Daniel</td><td>Oostelijk Havengebied - Indische Buurt</td><td>Private room</td><td>59</td><td>3</td><td>278</td><td>1.98</td><td>0</td><td>true</td><td>true</td></tr><tr><td>20168</td><td>Studio with private bathroom in the centre 1</td><td>59484</td><td>Alexander</td><td>Centrum-Oost</td><td>Private room</td><td>236</td><td>1</td><td>340</td><td>2.63</td><td>0</td><td>true</td><td>true</td></tr><tr><td>25428</td><td>Lovely apt in City Centre (w.lift) near Jordaan</td><td>56142</td><td>Joan</td><td>Centrum-West</td><td>Entire home/apt</td><td>125</td><td>14</td><td>5</td><td>0.15</td><td>58</td><td>true</td><td>true</td></tr></tbody></table></div>

# %%
#multiple bookings for single host_id

cleaned_airbnb_df.createOrReplaceTempView("host_id_count")
host_id_count = spark.sql("select host_id,count(*) as count from host_id_count group by host_id having count > 1 ")
host_id_count.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[107]: 1359</div>

# %%
display(host_id_count.limit(5))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>host_id</th><th>count</th></tr></thead><tbody><tr><td>1907015</td><td>2</td></tr><tr><td>6797351</td><td>2</td></tr><tr><td>9519520</td><td>2</td></tr><tr><td>2674028</td><td>3</td></tr><tr><td>7872614</td><td>2</td></tr></tbody></table></div>

# %%
#inner join on two DFs to get details about people having more than one bookings

inner_join = cleaned_airbnb_df.join(host_id_count, on=["host_id"],how = "inner")
display(inner_join.limit(5))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>host_id</th><th>id</th><th>name</th><th>host_name</th><th>neighbourhood</th><th>room_type</th><th>price</th><th>minimum_nights</th><th>number_of_reviews</th><th>reviews_per_month</th><th>availability_365</th><th>value_host_id</th><th>value_id</th><th>count</th></tr></thead><tbody><tr><td>59484</td><td>20168</td><td>Studio with private bathroom in the centre 1</td><td>Alexander</td><td>Centrum-Oost</td><td>Private room</td><td>236</td><td>1</td><td>340</td><td>2.63</td><td>0</td><td>true</td><td>true</td><td>2</td></tr><tr><td>124245</td><td>28871</td><td>Comfortable double room</td><td>Edwin</td><td>Centrum-West</td><td>Private room</td><td>75</td><td>2</td><td>336</td><td>2.72</td><td>340</td><td>true</td><td>true</td><td>2</td></tr><tr><td>124245</td><td>29051</td><td>Comfortable single room</td><td>Edwin</td><td>Centrum-West</td><td>Private room</td><td>55</td><td>2</td><td>481</td><td>4.13</td><td>361</td><td>true</td><td>true</td><td>2</td></tr><tr><td>187728</td><td>44129</td><td>Luxury design with canal view</td><td>Tatiana</td><td>Centrum-West</td><td>Entire home/apt</td><td>115</td><td>7</td><td>177</td><td>1.43</td><td>167</td><td>true</td><td>true</td><td>5</td></tr><tr><td>231806</td><td>50518</td><td>Perfect central Amsterdam apartment</td><td>Nikki</td><td>Westerpark</td><td>Entire home/apt</td><td>120</td><td>2</td><td>112</td><td>1.15</td><td>48</td><td>true</td><td>true</td><td>2</td></tr></tbody></table></div>

# %%
inner_join.dropDuplicates()
inner_join.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[110]: 3879</div>

# %%
inner_join = inner_join.select("id","name","host_id","count","host_name",\
                               "neighbourhood",
                  "room_type","price",
                  "minimum_nights",
                  "number_of_reviews",
                  "reviews_per_month",
                  "availability_365",)

display(inner_join.limit(5))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>name</th><th>host_id</th><th>count</th><th>host_name</th><th>neighbourhood</th><th>room_type</th><th>price</th><th>minimum_nights</th><th>number_of_reviews</th><th>reviews_per_month</th><th>availability_365</th></tr></thead><tbody><tr><td>20168</td><td>Studio with private bathroom in the centre 1</td><td>59484</td><td>2</td><td>Alexander</td><td>Centrum-Oost</td><td>Private room</td><td>236</td><td>1</td><td>340</td><td>2.63</td><td>0</td></tr><tr><td>28871</td><td>Comfortable double room</td><td>124245</td><td>2</td><td>Edwin</td><td>Centrum-West</td><td>Private room</td><td>75</td><td>2</td><td>336</td><td>2.72</td><td>340</td></tr><tr><td>29051</td><td>Comfortable single room</td><td>124245</td><td>2</td><td>Edwin</td><td>Centrum-West</td><td>Private room</td><td>55</td><td>2</td><td>481</td><td>4.13</td><td>361</td></tr><tr><td>44129</td><td>Luxury design with canal view</td><td>187728</td><td>5</td><td>Tatiana</td><td>Centrum-West</td><td>Entire home/apt</td><td>115</td><td>7</td><td>177</td><td>1.43</td><td>167</td></tr><tr><td>50518</td><td>Perfect central Amsterdam apartment</td><td>231806</td><td>2</td><td>Nikki</td><td>Westerpark</td><td>Entire home/apt</td><td>120</td><td>2</td><td>112</td><td>1.15</td><td>48</td></tr></tbody></table></div>

# %%
#maximum number of bookings for particular rooms

inner_join.createOrReplaceTempView("inner_join_view")
room_type_count = spark.sql("select room_type,count(*) as count from inner_join_view group by room_type")
display(room_type_count)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>room_type</th><th>count</th></tr></thead><tbody><tr><td>Shared room</td><td>27</td></tr><tr><td>Hotel room</td><td>112</td></tr><tr><td>Entire home/apt</td><td>2060</td></tr><tr><td>Private room</td><td>1680</td></tr></tbody></table></div>
